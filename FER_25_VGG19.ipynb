# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

IMG_SIZE = (224, 224)
BATCH_SIZE = 128

# Data augmentation and preprocessing
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
)

# Load training data
train_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
)

# Load validation data
validation_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
)
# Load and preprocess test images
test_generator = datagen.flow_from_directory(
    '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Test',  # Path to the test dataset
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)
# Out:
# Found 5846 images belonging to 7 classes.
# Found 647 images belonging to 7 classes.
# Found 717 images belonging to 7 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# Define your data paths
train_data_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Train'
test_data_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Test'

# Define your emotion categories
emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

# Initialize counts for each category
train_counts = {emotion: 0 for emotion in emotion_categories}
test_counts = {emotion: 0 for emotion in emotion_categories}

# Count images in train dataset
for emotion in emotion_categories:
    emotion_path = os.path.join(train_data_path, emotion)
    train_counts[emotion] = len(os.listdir(emotion_path))

# Count images in test dataset
for emotion in emotion_categories:
    emotion_path = os.path.join(test_data_path, emotion)
    test_counts[emotion] = len(os.listdir(emotion_path))

df = pd.DataFrame({
    'Emotion': emotion_categories,
    'Train Count': list(train_counts.values()),
    'Test Count': list(test_counts.values())
})

# Get the positions for the bars
x = np.arange(len(emotion_categories))
width = 0.35  # Width of the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width/2, df['Train Count'], width, label='Train')
rects2 = ax.bar(x + width/2, df['Test Count'], width, label='Test')

# Add labels, title, and legend
ax.set_xlabel('Emotion Categories')
ax.set_ylabel('Number of Images')
ax.set_title('Image Distribution Across Emotion Categories')
ax.set_xticks(x)
ax.set_xticklabels(emotion_categories)
ax.legend()

# Add count labels using the provided code snippet
for index, row in df.iterrows():
    plt.text(x=index - width/2, y=row['Train Count'] + 10, s=str(row['Train Count']), ha='center', va='bottom', fontsize=10)
    plt.text(x=index + width/2, y=row['Test Count'] + 10, s=str(row['Test Count']), ha='center', va='bottom', fontsize=10)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
import random

def plot_sample_images(img_paths, labels, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
    for i, img_path in enumerate(img_paths[:num_images]):
        img = Image.open(img_path)
        axes[i].imshow(img, cmap='gray')
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()

# Define your data paths and emotion categories
data_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Train'
emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']
for emotion in emotion_categories:
    emotion_path = os.path.join(data_path, emotion)
    all_img_files = os.listdir(emotion_path)
    random_img_files = random.sample(all_img_files, 5)
    img_paths = [os.path.join(emotion_path, img_file) for img_file in random_img_files]
    plot_sample_images(img_paths, [emotion] * len(img_paths))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import random

# Define data augmentation
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values to [0, 1]
    rotation_range=20,  # Add rotation
    width_shift_range=0.2,  # Add width shift
    height_shift_range=0.2, # Add height shift
    brightness_range=[0.8, 1.2], # Add brightness adjustment
    shear_range=0.2,  # Apply shearing for data augmentation
    zoom_range=0.2,   # Randomly zoom into images
    horizontal_flip=True,  # Randomly flip images horizontally
    fill_mode='nearest'
)

# Define your data paths and emotion categories
data_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Train'
emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

# Loop through each emotion category and plot sample images
for emotion in emotion_categories:
    emotion_path = os.path.join(data_path, emotion)

    # Randomly select an image from the directory
    img_name = random.choice(os.listdir(emotion_path))
    img_path = os.path.join(emotion_path, img_name)

    # Load a single image and apply augmentation
    img = Image.open(img_path).resize((224, 224))
    img = img.convert('RGB')  # Ensure RGB format
    img = np.array(img)
    img = img.reshape((1, 224, 224, 3))

    # Generate augmented images
    augmented_imgs = [datagen.flow(img, batch_size=1).__next__()[0] for _ in range(5)]

    # Plot original and augmented images
    fig, axes = plt.subplots(1, 6, figsize=(20, 5))
    axes[0].imshow(img[0].astype('uint8'))  # Original image
    axes[0].set_title(f"Original {emotion} Image")

    for i, aug_img in enumerate(augmented_imgs):
        aug_img = (aug_img * 255).astype('uint8')  # Rescale augmented image to 0-255
        axes[i + 1].imshow(aug_img)
        axes[i + 1].set_title(f"Augmented {emotion} Image {i+1}")

    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# Create Precision and Recall metrics outside the function
precision_metric = Precision()
recall_metric = Recall()

# Custom F1-score metric
def f1_score(y_true, y_pred):
    precision = precision_metric(y_true, y_pred)  # Use pre-created metric
    recall = recall_metric(y_true, y_pred)       # Use pre-created metric
    f1 = 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))
    return f1

# Apply mixed precision for faster training and less GPU load
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# Load pre-trained VGG19 model without the top classification layer
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model to retain pre-trained weights
base_model.trainable = False

# Add custom classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
# Apply the output layer to the previous layer's output
output = Dense(7, activation='softmax')(x)  # 7 classes: anger, disgust, fear, happiness, neutral, sadness, and surprise

# Create the final model
model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ cast (Cast)                          │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,290,631 (77.40 MB)
#  Trainable params: 266,247 (1.02 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), f1_score]
)
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=30,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6499s 144s/step - accuracy: 0.1626 - f1_score: 0.1269 - loss: 6.5292 - precision: 0.1629 - recall: 0.1484 - val_accuracy: 0.4187 - val_f1_score: 0.2329 - val_loss: 1.7768 - val_precision: 0.5115 - val_recall: 0.3141
# Epoch 2/30
#  1/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.4453 - f1_score: 0.2419 - loss: 2.0514 - precision: 0.4510 - recall: 0.3594
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 287ms/step - accuracy: 0.4453 - f1_score: 0.2419 - loss: 2.0514 - precision: 0.4510 - recall: 0.3594 - val_accuracy: 0.4141 - val_f1_score: 0.2482 - val_loss: 1.7845 - val_precision: 0.4974 - val_recall: 0.3000
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.3976 - f1_score: 0.2669 - loss: 1.7609 - precision: 0.4968 - recall: 0.2711 - val_accuracy: 0.4125 - val_f1_score: 0.2843 - val_loss: 1.5420 - val_precision: 0.5806 - val_recall: 0.1969
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.4141 - f1_score: 0.2845 - loss: 1.4787 - precision: 0.5532 - recall: 0.2031 - val_accuracy: 0.4313 - val_f1_score: 0.2853 - val_loss: 1.4784 - val_precision: 0.6802 - val_recall: 0.2094
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.4597 - f1_score: 0.2920 - loss: 1.4406 - precision: 0.6116 - recall: 0.2579 - val_accuracy: 0.4641 - val_f1_score: 0.3082 - val_loss: 1.4237 - val_precision: 0.6398 - val_recall: 0.2359
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.4453 - f1_score: 0.3093 - loss: 1.4206 - precision: 0.6154 - recall: 0.3125 - val_accuracy: 0.4906 - val_f1_score: 0.3102 - val_loss: 1.3857 - val_precision: 0.6653 - val_recall: 0.2547
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.4947 - f1_score: 0.3166 - loss: 1.3629 - precision: 0.6353 - recall: 0.2964 - val_accuracy: 0.4906 - val_f1_score: 0.3305 - val_loss: 1.3916 - val_precision: 0.6606 - val_recall: 0.2828
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.5078 - f1_score: 0.3313 - loss: 1.2241 - precision: 0.6393 - recall: 0.3047 - val_accuracy: 0.4969 - val_f1_score: 0.3320 - val_loss: 1.3772 - val_precision: 0.6605 - val_recall: 0.2797
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.5324 - f1_score: 0.3397 - loss: 1.2530 - precision: 0.6858 - recall: 0.3614 - val_accuracy: 0.5031 - val_f1_score: 0.3570 - val_loss: 1.3448 - val_precision: 0.6677 - val_recall: 0.3359
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.5234 - f1_score: 0.3579 - loss: 1.2797 - precision: 0.6825 - recall: 0.3359 - val_accuracy: 0.4781 - val_f1_score: 0.3590 - val_loss: 1.3386 - val_precision: 0.6820 - val_recall: 0.3250
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.5588 - f1_score: 0.3645 - loss: 1.2029 - precision: 0.6954 - recall: 0.3707 - val_accuracy: 0.5109 - val_f1_score: 0.3774 - val_loss: 1.3833 - val_precision: 0.6289 - val_recall: 0.3469
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.5234 - f1_score: 0.3781 - loss: 1.3890 - precision: 0.6267 - recall: 0.3672 - val_accuracy: 0.5047 - val_f1_score: 0.3787 - val_loss: 1.3346 - val_precision: 0.6476 - val_recall: 0.3359
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.5558 - f1_score: 0.3832 - loss: 1.1830 - precision: 0.7030 - recall: 0.3890 - val_accuracy: 0.5453 - val_f1_score: 0.3956 - val_loss: 1.2822 - val_precision: 0.6749 - val_recall: 0.3828
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.5938 - f1_score: 0.3965 - loss: 1.1409 - precision: 0.7250 - recall: 0.4531 - val_accuracy: 0.5406 - val_f1_score: 0.3972 - val_loss: 1.2750 - val_precision: 0.6854 - val_recall: 0.3812
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.5790 - f1_score: 0.4018 - loss: 1.1111 - precision: 0.7095 - recall: 0.4222 - val_accuracy: 0.5109 - val_f1_score: 0.4125 - val_loss: 1.3073 - val_precision: 0.6243 - val_recall: 0.3531
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.5391 - f1_score: 0.4128 - loss: 1.1408 - precision: 0.6216 - recall: 0.3594 - val_accuracy: 0.5516 - val_f1_score: 0.4133 - val_loss: 1.2280 - val_precision: 0.6757 - val_recall: 0.3875
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6115 - f1_score: 0.4179 - loss: 1.0729 - precision: 0.7353 - recall: 0.4614 - val_accuracy: 0.5406 - val_f1_score: 0.4274 - val_loss: 1.2730 - val_precision: 0.6978 - val_recall: 0.3969
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.5781 - f1_score: 0.4280 - loss: 1.0566 - precision: 0.7403 - recall: 0.4453 - val_accuracy: 0.5328 - val_f1_score: 0.4284 - val_loss: 1.2846 - val_precision: 0.6740 - val_recall: 0.3812
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.5914 - f1_score: 0.4318 - loss: 1.0925 - precision: 0.7276 - recall: 0.4505 - val_accuracy: 0.5531 - val_f1_score: 0.4396 - val_loss: 1.2494 - val_precision: 0.6832 - val_recall: 0.4313
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.6875 - f1_score: 0.4404 - loss: 0.9143 - precision: 0.8554 - recall: 0.5547 - val_accuracy: 0.5484 - val_f1_score: 0.4408 - val_loss: 1.2451 - val_precision: 0.6777 - val_recall: 0.4141
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6368 - f1_score: 0.4446 - loss: 1.0106 - precision: 0.7565 - recall: 0.4932 - val_accuracy: 0.5453 - val_f1_score: 0.4524 - val_loss: 1.2857 - val_precision: 0.6809 - val_recall: 0.4000
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.6094 - f1_score: 0.4528 - loss: 1.0917 - precision: 0.7465 - recall: 0.4141 - val_accuracy: 0.5344 - val_f1_score: 0.4530 - val_loss: 1.2639 - val_precision: 0.6430 - val_recall: 0.3969
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6241 - f1_score: 0.4557 - loss: 1.0098 - precision: 0.7392 - recall: 0.4823 - val_accuracy: 0.5594 - val_f1_score: 0.4627 - val_loss: 1.2409 - val_precision: 0.7008 - val_recall: 0.4172
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.6016 - f1_score: 0.4630 - loss: 0.9823 - precision: 0.7037 - recall: 0.4453 - val_accuracy: 0.5500 - val_f1_score: 0.4632 - val_loss: 1.2655 - val_precision: 0.6770 - val_recall: 0.4094
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6327 - f1_score: 0.4661 - loss: 1.0005 - precision: 0.7570 - recall: 0.5079 - val_accuracy: 0.5828 - val_f1_score: 0.4722 - val_loss: 1.1956 - val_precision: 0.7131 - val_recall: 0.4156
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.5391 - f1_score: 0.4726 - loss: 1.0997 - precision: 0.7059 - recall: 0.4688 - val_accuracy: 0.5531 - val_f1_score: 0.4728 - val_loss: 1.2081 - val_precision: 0.6734 - val_recall: 0.4156
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6429 - f1_score: 0.4750 - loss: 0.9936 - precision: 0.7514 - recall: 0.4967 - val_accuracy: 0.5641 - val_f1_score: 0.4808 - val_loss: 1.2219 - val_precision: 0.6734 - val_recall: 0.4156
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.6562 - f1_score: 0.4811 - loss: 0.9946 - precision: 0.7895 - recall: 0.4688 - val_accuracy: 0.5469 - val_f1_score: 0.4812 - val_loss: 1.2053 - val_precision: 0.6716 - val_recall: 0.4219
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6537 - f1_score: 0.4834 - loss: 0.9360 - precision: 0.7522 - recall: 0.5145 - val_accuracy: 0.5703 - val_f1_score: 0.4896 - val_loss: 1.1699 - val_precision: 0.6818 - val_recall: 0.4453
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.6172 - f1_score: 0.4899 - loss: 1.0037 - precision: 0.6882 - recall: 0.5000 - val_accuracy: 0.6078 - val_f1_score: 0.4902 - val_loss: 1.1555 - val_precision: 0.6968 - val_recall: 0.4812

# %%
# Evaluate the model and unpack the returned values appropriately
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model.evaluate(validation_generator)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5519 - f1_score: 0.4904 - loss: 1.2601 - precision: 0.6504 - recall: 0.4140
# Test Accuracy: 54.56%

# %%
# Unfreeze the base model for fine-tuning
base_model.trainable = True

# Use a lower learning rate for fine-tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), f1_score]
)

# Fine-tune the model
fine_tune_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=30,  # Add more epochs for fine-tuning
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.1500 - f1_score: 0.3207 - loss: 1.9457 - precision: 0.3391 - recall: 2.5684e-04 - val_accuracy: 0.1469 - val_f1_score: 0.3153 - val_loss: 1.9460 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.1484 - f1_score: 0.3149 - loss: 1.9457 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1437 - val_f1_score: 0.3144 - val_loss: 1.9488 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.1466 - f1_score: 0.3123 - loss: 1.9460 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1500 - val_f1_score: 0.3072 - val_loss: 1.9462 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.1406 - f1_score: 0.3068 - loss: 1.9449 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1422 - val_f1_score: 0.3064 - val_loss: 1.9450 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.1448 - f1_score: 0.3044 - loss: 1.9440 - precision: 0.5032 - recall: 7.1411e-04 - val_accuracy: 0.1375 - val_f1_score: 0.2995 - val_loss: 1.9444 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.1172 - f1_score: 0.2991 - loss: 1.9492 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1437 - val_f1_score: 0.2987 - val_loss: 1.9495 - val_precision: 0.5000 - val_recall: 0.0016
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1539 - f1_score: 0.2969 - loss: 1.9451 - precision: 0.2790 - recall: 1.5629e-04 - val_accuracy: 0.1375 - val_f1_score: 0.2922 - val_loss: 1.9470 - val_precision: 0.3333 - val_recall: 0.0016
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.1641 - f1_score: 0.2918 - loss: 1.9434 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1375 - val_f1_score: 0.2915 - val_loss: 1.9578 - val_precision: 0.2500 - val_recall: 0.0016
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1476 - f1_score: 0.2897 - loss: 1.9486 - precision: 0.4256 - recall: 7.5415e-04 - val_accuracy: 0.1375 - val_f1_score: 0.2853 - val_loss: 1.9494 - val_precision: 0.2500 - val_recall: 0.0016
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.1797 - f1_score: 0.2849 - loss: 1.9461 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1375 - val_f1_score: 0.2846 - val_loss: 1.9433 - val_precision: 0.3333 - val_recall: 0.0016
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1497 - f1_score: 0.2829 - loss: 1.9428 - precision: 0.2744 - recall: 5.5252e-04 - val_accuracy: 0.1500 - val_f1_score: 0.2787 - val_loss: 1.9449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.1328 - f1_score: 0.2783 - loss: 1.9475 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1484 - val_f1_score: 0.2780 - val_loss: 1.9451 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1569 - f1_score: 0.2763 - loss: 1.9443 - precision: 0.3286 - recall: 3.6811e-04 - val_accuracy: 0.1391 - val_f1_score: 0.2723 - val_loss: 1.9428 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - accuracy: 0.1328 - f1_score: 0.2720 - loss: 1.9490 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1484 - val_f1_score: 0.2717 - val_loss: 1.9453 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1713 - f1_score: 0.2701 - loss: 1.9395 - precision: 0.4910 - recall: 0.0014 - val_accuracy: 0.1500 - val_f1_score: 0.2663 - val_loss: 1.9387 - val_precision: 0.5000 - val_recall: 0.0016
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.1250 - f1_score: 0.2660 - loss: 1.9418 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1422 - val_f1_score: 0.2657 - val_loss: 1.9487 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1637 - f1_score: 0.2642 - loss: 1.9407 - precision: 0.4264 - recall: 0.0012 - val_accuracy: 0.1516 - val_f1_score: 0.2605 - val_loss: 1.9447 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.1250 - f1_score: 0.2602 - loss: 1.9478 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1500 - val_f1_score: 0.2599 - val_loss: 1.9435 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1513 - f1_score: 0.2585 - loss: 1.9444 - precision: 0.0217 - recall: 7.6038e-06 - val_accuracy: 0.1516 - val_f1_score: 0.2550 - val_loss: 1.9427 - val_precision: 0.2500 - val_recall: 0.0016
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.1484 - f1_score: 0.2547 - loss: 1.9553 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1516 - val_f1_score: 0.2544 - val_loss: 1.9443 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.1688 - f1_score: 0.2530 - loss: 1.9381 - precision: 0.7254 - recall: 0.0027 - val_accuracy: 0.1578 - val_f1_score: 0.2497 - val_loss: 1.9393 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.1719 - f1_score: 0.2494 - loss: 1.9326 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1469 - val_f1_score: 0.2492 - val_loss: 1.9400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1680 - f1_score: 0.2478 - loss: 1.9367 - precision: 0.5549 - recall: 0.0012 - val_accuracy: 0.1672 - val_f1_score: 0.2446 - val_loss: 1.9364 - val_precision: 0.2000 - val_recall: 0.0016
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.1250 - f1_score: 0.2444 - loss: 1.9409 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1531 - val_f1_score: 0.2441 - val_loss: 1.9377 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.1691 - f1_score: 0.2429 - loss: 1.9360 - precision: 0.4060 - recall: 0.0012 - val_accuracy: 0.1641 - val_f1_score: 0.2398 - val_loss: 1.9446 - val_precision: 0.2500 - val_recall: 0.0031
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.1562 - f1_score: 0.2396 - loss: 1.9532 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1594 - val_f1_score: 0.2393 - val_loss: 1.9425 - val_precision: 0.2500 - val_recall: 0.0031
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1855 - f1_score: 0.2381 - loss: 1.9267 - precision: 0.5923 - recall: 0.0054 - val_accuracy: 0.1688 - val_f1_score: 0.2352 - val_loss: 1.9359 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.1953 - f1_score: 0.2350 - loss: 1.9251 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1594 - val_f1_score: 0.2347 - val_loss: 1.9384 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.1910 - f1_score: 0.2336 - loss: 1.9222 - precision: 0.5902 - recall: 0.0061 - val_accuracy: 0.1688 - val_f1_score: 0.2308 - val_loss: 1.9355 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.1562 - f1_score: 0.2306 - loss: 1.9412 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1750 - val_f1_score: 0.2303 - val_loss: 1.9334 - val_precision: 0.3333 - val_recall: 0.0016

# %%
# Evaluate the model and unpack the returned values appropriately
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model.evaluate(validation_generator)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.1768 - f1_score: 0.2300 - loss: 1.9365 - precision: 0.7143 - recall: 0.0013
# Test Accuracy: 17.00%

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.plot(fine_tune_history.history['accuracy'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_accuracy'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# Plot training & validation loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.plot(fine_tune_history.history['loss'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_loss'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# Plot training & validation precision
plt.plot(history.history['precision'], label='Train')
plt.plot(history.history['val_precision'], label='Validation')
plt.plot(fine_tune_history.history['precision'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_precision'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.title('Training and Validation Precision')
plt.show()

# %%
# Plot training & validation recall
plt.plot(history.history['recall'], label='Train')
plt.plot(history.history['val_recall'], label='Validation')
plt.plot(fine_tune_history.history['recall'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_recall'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.title('Training and Validation Recall')
plt.show()

# %%
# Plot training & validation f1_score
plt.plot(history.history['f1_score'], label='Train')
plt.plot(history.history['val_f1_score'], label='Validation')
plt.plot(fine_tune_history.history['f1_score'], label='Fine-Tune Train')
plt.plot(fine_tune_history.history['val_f1_score'], label='Fine-Tune Validation')
plt.xlabel('Epochs')
plt.ylabel('F1_score')
plt.legend()
plt.title('Training and Validation F1_score')
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

y_pred_prob = model.predict(validation_generator)
y_val = validation_generator.classes
plt.figure(figsize=(10, 8))

# Initialize dictionaries before the loop
fpr = dict()
tpr = dict()
roc_auc = dict()

# Calculate ROC curve and AUC for each class inside the loop
n_classes = len(emotion_categories)  # Ensure n_classes is correct
y_val_binary = label_binarize(y_val, classes=range(n_classes)) # Binarize with correct classes

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_binary[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i], lw=2,
             label=f'{emotion_categories[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Chance', alpha=0.8)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Class Classification')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']
y_pred_prob = model.predict(validation_generator)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = y_val

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Function to plot confusion matrix
def plot_confusion_matrix_custom(cm, class_names):
    """Custom heatmap for the confusion matrix."""
    plt.figure(figsize=(10, 8))  # Adjust size if needed
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()
# Plot the confusion matrix
plot_confusion_matrix_custom(cm, emotion_categories)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step

# %%
model.save('/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25_VGG19.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !pip install tf-keras-vis
# Out:
# Collecting tf-keras-vis
#   Downloading tf_keras_vis-0.8.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (1.13.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (11.1.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (1.2.18)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (2.36.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tf-keras-vis) (24.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->tf-keras-vis) (1.17.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio->tf-keras-vis) (1.26.4)
# Downloading tf_keras_vis-0.8.7-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: tf-keras-vis
# Successfully installed tf-keras-vis-0.8.7

# %%
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils import normalize
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os
import random

def grad_cam_heatmap(model, image, layer_name='block4_conv3'): # Changed penultimate layer name to 'top_activation'
    gradcam = Gradcam(model, clone=False)

    def loss(output):
        predicted_class = np.argmax(model.predict(image))
        return output[:, predicted_class]

    cam = gradcam(loss, image, penultimate_layer=layer_name)
    cam = normalize(cam)
    return cam

# Define emotion categories
emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

data_path = '/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Test'

# Loop through each emotion category
for emotion in emotion_categories:
    print(f"Processing emotion: {emotion}")
    emotion_path = os.path.join(data_path, emotion)
    img_names = os.listdir(emotion_path)

    if len(img_names) < 3:
        print(f"Skipping {emotion}, not enough images.")
        continue

    img_paths = random.sample([os.path.join(emotion_path, img) for img in img_names], 3)

    # Process 3 randomly selected images per emotion
    for img_path in img_paths:
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        heatmap = grad_cam_heatmap(model, x) # Now calls the function with updated penultimate_layer
        heatmap = np.uint8(255 * heatmap[0])

        fig, axes = plt.subplots(1, 2, figsize=(10, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original Image")
        axes[0].axis('off')

        axes[1].imshow(img)
        axes[1].imshow(heatmap, cmap='jet', alpha=0.5)
        predicted_emotion = emotion_categories[np.argmax(model.predict(x))]
        axes[1].set_title(f"Predicted Emotion: {predicted_emotion}")
        axes[1].axis('off')

        plt.tight_layout()
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus
from tf_keras_vis.utils import normalize
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os
import random

# Define emotion categories
emotion_categories = ['Anger', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

# Function to get random images
def get_random_images(emotion_path, num_images=3, random_state=None):
    """Returns a list of paths to random images from the given emotion path."""
    if random_state:
        random.seed(random_state)  # Set random seed for reproducibility
    image_files = os.listdir(emotion_path)
    random_images = random.sample(image_files, num_images)
    return [os.path.join(emotion_path, img) for img in random_images]

def grad_cam_plus_plus_heatmap(model, image, layer_name='block4_conv3'):
    gradcam_plus_plus = GradcamPlusPlus(model, clone=False)

    def loss(output):
        predicted_class = np.argmax(model.predict(image))
        return output[:, predicted_class]

    cam = gradcam_plus_plus(loss, image, penultimate_layer=layer_name)
    cam = normalize(cam)
    return cam # Added indentation here

# Set random seed (you can change this to any integer)
random_state = 47

# Loop through each emotion category
for emotion in emotion_categories:
    print(f"Processing emotion: {emotion}")
    emotion_path = os.path.join('/content/drive/My Drive/Facial_Emotion_Recognition_Project/FER_25/Test', emotion)

    # Get random image paths using the function with random state
    img_paths = get_random_images(emotion_path, num_images=3, random_state=random_state)

     # Loop through 3 images for each emotion
    for i, img_path in enumerate(img_paths):
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        heatmap = grad_cam_plus_plus_heatmap(model, x)
        heatmap = np.uint8(255 * heatmap[0])

        fig, axes = plt.subplots(1, 2, figsize=(10, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original Image")
        axes[0].axis('off')

        axes[1].imshow(img)
        axes[1].imshow(heatmap, cmap='jet', alpha=0.5)
        predicted_emotion = emotion_categories[np.argmax(model.predict(x))]
        axes[1].set_title(f"Predicted Emotion: {predicted_emotion}")
        axes[1].axis('off')

        plt.tight_layout()
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
